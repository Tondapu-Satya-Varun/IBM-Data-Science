# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Tondapu Satya Varun__
#
# Undergraduate Student

# %% [markdown]
# _I am interested in Data Science because it can solve many problems persisting in various industries by making use of the available data_

# %% [markdown]
# ### The code in the next cell is supposed to print the message "Hello World"

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# __1)Image:__
#
# ![frp-boats-500x500.jpg](attachment:6cdc92e3-f308-4efb-8054-dc4531fe5724.jpg)
#
#
# __2)Bulleted list:__
#
# Programming languages for Data Science:
# - Python
# - R
# - SQL
#
#
# __3)Table:__
#
#
# |country|India|Australia|England|
# |-------|-----|---------|-------|
# |Points |  6  |    5    |   3   |
